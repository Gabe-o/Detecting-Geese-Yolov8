# %%
from ultralytics.utils.benchmarks import benchmark

# %%
benchmark(model='../../../training/imgsz256/runs/detect/train/weights/best.pt', data='config.yaml', imgsz=256)
# Out:
# Setup complete ✅ (8 CPUs, 31.2 GB RAM, 38.0/97.9 GB disk)
#
# Benchmarks complete for best.pt on config.yaml at imgsz=256 (164.50s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)
# 0                 PyTorch       ✅        6.0               0.3279                  299.51
# 1             TorchScript       ✅       11.8               0.3410                  139.99
# 2                    ONNX       ✅       11.5               0.3410                   23.80
# 3                OpenVINO       ✅       11.7               0.3410                    7.15
# 4                TensorRT       ❌        0.0                  NaN                     NaN
# 5                  CoreML       ❎        5.8                  NaN                     NaN
# 6   TensorFlow SavedModel       ✅       29.0               0.3410                   15.90
# 7     TensorFlow GraphDef       ✅       11.6               0.3410                   18.75
# ...
