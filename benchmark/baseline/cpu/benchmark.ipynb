# %%
from ultralytics.utils.benchmarks import benchmark

# %%
benchmark(model='../../../training/baseline/runs/detect/train/weights/best.pt', data='config.yaml', imgsz=640)
# Out:
# Setup complete ✅ (8 CPUs, 31.2 GB RAM, 38.0/97.9 GB disk)
#
# Benchmarks complete for best.pt on config.yaml at imgsz=640 (283.04s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)
# 0                 PyTorch       ✅        6.0               0.4501                  468.63
# 1             TorchScript       ✅       11.9               0.4091                  329.59
# 2                    ONNX       ✅       11.7               0.4091                   72.24
# 3                OpenVINO       ✅       11.8               0.4091                   59.81
# 4                TensorRT       ❌        0.0                  NaN                     NaN
# 5                  CoreML       ❎        5.9                  NaN                     NaN
# 6   TensorFlow SavedModel       ✅       29.2               0.4091                   52.39
# 7     TensorFlow GraphDef       ✅       11.7               0.4091                   62.92
# ...
