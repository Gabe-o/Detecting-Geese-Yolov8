# %%
from ultralytics.utils.benchmarks import benchmark

# %%
benchmark(model='../../../training/no_augmentation/runs/detect/train/weights/best.pt', data='config.yaml', imgsz=640, device=0)
# Out:
# Setup complete ✅ (8 CPUs, 31.2 GB RAM, 38.0/97.9 GB disk)
#
# Benchmarks complete for best.pt on config.yaml at imgsz=640 (220.86s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)
# 0                 PyTorch       ✅        6.0               0.0248                   21.22
# 1             TorchScript       ✅       11.9               0.0347                   19.03
# 2                    ONNX       ✅       11.7               0.0347                   72.58
# 3                OpenVINO       ❌        0.0                  NaN                     NaN
# 4                TensorRT       ❎       12.7                  NaN                     NaN
# 5                  CoreML       ❌        0.0                  NaN                     NaN
# 6   TensorFlow SavedModel       ✅       29.2               0.0347                   51.89
# 7     TensorFlow GraphDef       ✅       11.7               0.0347                   52.17
# ...
