# %%
from ultralytics.utils.benchmarks import benchmark

# %%
benchmark(model='../../../training/small/runs/detect/train/weights/best.pt', data='config.yaml', imgsz=640)
# Out:
# Setup complete ✅ (8 CPUs, 31.2 GB RAM, 38.0/97.9 GB disk)
#
# Benchmarks complete for best.pt on config.yaml at imgsz=640 (517.42s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)
# 0                 PyTorch       ✅       21.5               0.4871                 1407.52
# 1             TorchScript       ✅       42.9               0.4287                  799.32
# 2                    ONNX       ✅       42.6               0.4287                  140.33
# 3                OpenVINO       ✅       42.8               0.4287                  121.95
# 4                TensorRT       ❌        0.0                  NaN                     NaN
# 5                  CoreML       ❎       21.4                  NaN                     NaN
# 6   TensorFlow SavedModel       ✅      106.7               0.4287                  105.42
# 7     TensorFlow GraphDef       ✅       42.7               0.4287                  114.42
# ...
